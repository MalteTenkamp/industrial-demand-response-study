# %%
#feiertage müssen noch händisch genullt werden!

import pandas as pd
from pathlib import Path

dates = pd.date_range("2024-01-01", "2024-12-31", freq="D")

df = pd.DataFrame({"date": dates})
df["werktag"] = (df["date"].dt.weekday < 5).astype(int)

output_path = Path("../data/business_days.csv")
output_path.parent.mkdir(parents=True, exist_ok=True)

df.to_csv(output_path, index=False)

print(f"CSV gespeichert unter: {output_path}")
# Out:
# CSV gespeichert unter: data\business_days.csv
